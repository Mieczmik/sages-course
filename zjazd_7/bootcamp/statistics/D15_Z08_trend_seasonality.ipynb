# %% [markdown]
# # Trend and Seasonality

# %%
import numpy as np
import pandas as pd
from pandas import read_csv
from pandas import datetime
from pandas import Series
import matplotlib.pyplot as plt
# Out:
# /tmp/ipykernel_17083/2128904682.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %% [markdown]
# Dekompozycja szeregów czasowych opiera się na myślenie o szeregu czasowym jako kombinacji:
#
# - trendu,
# - sezonowości,
# - szumu.
#
#
# Szereg czasowy zazwyczaj składa się z części powtarzającej się i szumu:
#
# - Level: Średnia wartość w szeregu czasowym.
# - Trend: Wzrastająca lub malejąca wartość w szeregu czasowym.
# - Seasonality:  powtarzający się cykl krótkoterminowy w szeregu czasowym.
# - Noise : losowe zaburzenia w szeregu czasowym.
#
# Uważa się, że szereg czasowy jest agregatem lub kombinacją tych czterech elementów.
# Wszystkie szeregi czasowe mają poziom (level) i szum. Elementy trendu i sezonowości są opcjonalne.
#
# ### Additive Model
#
# y(t) = Level + Trend + Seasonality + Noise
#
# ### Multiplicative Model
#
# y(t) = Level * Trend * Seasonality * Noise

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from random import randrange

# %% [markdown]
# # Przykład
# Dla poniższych danych wykonaj dekompozycję zarówno <tt>additive</tt> jak i <tt>multiplicative</tt> na:
# - trend
# - sezonowość
# - szum

# %%
data = [i+randrange(10) for i in range(1,100)]
series = pd.Series(data)

# %%
plt.figure(figsize=(10,6));
series.plot()
plt.show()

# %%
result = seasonal_decompose(data, model='additive', period=1)

# %%
plt.figure(figsize=(12,8));
plt.subplot(411)
plt.plot(result.observed, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(result.trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(result.seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(result.resid, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Zadanie
# Dla poniższych danych wykonaj dekompozycję zarówno <tt>additive</tt> jak i <tt>multiplicative</tt> na:
# - trend
# - sezonowość
# - szum

# %%
series = [i + np.sin(i) for i in range(1,100)]

# %%
result = seasonal_decompose(series, model='additive', period=1)

# %%
plt.figure(figsize=(12,8));
plt.subplot(411)
plt.plot(result.observed, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(result.trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(result.seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(result.resid, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Zadanie
# Dla poniższych danych wykonaj dekompozycję zarówno <tt>additive</tt> jak i <tt>multiplicative</tt> na:
# - trend
# - sezonowość
# - szum

# %%
import pandas as pd
series = pd.read_csv('daily-minimum-temperatures.csv', index_col = 0, squeeze = True, parse_dates=['Date'])
# Out:
# /tmp/ipykernel_17083/2429389783.py:2: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('daily-minimum-temperatures.csv', index_col = 0, squeeze = True, parse_dates=['Date'])

# %%
result = seasonal_decompose(series, model='additive', period=365)
plt.figure(figsize=(12,8));
plt.subplot(411)
plt.plot(result.observed, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(result.trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(result.seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(result.resid, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
result = seasonal_decompose(series+273, model='multiplicative', period=365)
plt.figure(figsize=(12,8));
plt.subplot(411)
plt.plot(result.observed, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(result.trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(result.seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(result.resid, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Zadanie
# Dla poniższych danych wykonaj dekompozycję zarówno <tt>additive</tt> jak i <tt>multiplicative</tt> na:
# - trend
# - sezonowość
# - szum

# %%
import pandas as pd
series = pd.read_csv('international-airline-passengers.csv', index_col = 0, squeeze = True, parse_dates=['Month'])
# Out:
# /tmp/ipykernel_17083/3046638753.py:2: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('international-airline-passengers.csv', index_col = 0, squeeze = True, parse_dates=['Month'])

# %%
series
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
#              ...
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
# Name: International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60, Length: 144, dtype: int64

# %%
result = seasonal_decompose(series, model='additive', period=12)
plt.figure(figsize=(12,8));
plt.subplot(411)
plt.plot(result.observed, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(result.trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(result.seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(result.resid, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
result = seasonal_decompose(series, model='multiplicative', period=12)
plt.figure(figsize=(12,8));
plt.subplot(411)
plt.plot(result.observed, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(result.trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(result.seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(result.resid, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()
