# %% [markdown]
# # Underfitting vs. Overfitting

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn import  metrics

# %% [markdown]
# Rozważmy następujący zbiór punktów:

# %%
np.random.seed(0)
n_samples = 30
true_fun = lambda X: np.cos(1.5 * np.pi * X)
X = np.sort(np.random.rand(n_samples))
y = true_fun(X) + np.random.randn(n_samples) * 0.1

# %%
# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,1])
axes.set_ylim([-1.5,1.5])
plt.scatter(X, y,  color='black')
x_tr = np.linspace(0, 1, 200)
plt.show()

# %% [markdown]
# # Zadanie
# Podziel dane na dwie grupy.

# %%
s=np.random.random_sample(n_samples)
s[s>0.2]=1
s[s<=0.2]=0
s
X1=X[s==1]
y1=y[s==1]
X2=X[s==0]
y2=y[s==0]

# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,1])
axes.set_ylim([-1.5,1.5])
plt.scatter(X1, y1,  color='blue')
plt.scatter(X2, y2,  color='red')
x_tr = np.linspace(0, 1, 200)
plt.show()

# %% [markdown]
# # Zadanie
# Wykonaj regresję:
# * liniową

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn import datasets, linear_model

from sklearn import  metrics

res_tab_1 = []
res_tab_2 = []
res_tab_3 = []
res_tab_4 = []
res_tab_5 = []
res_tab_6 = []
res_tab_7 = []
res_tab_8 = []
res_tab_9 = []
res_tab_10 = []

for i in np.arange(100):
    
    s=np.random.random_sample(n_samples)
    s[s>0.2]=1
    s[s<=0.2]=0
    s
    X1=X[s==1]
    y1=y[s==1]
    X2=X[s==0]
    y2=y[s==0]
    
    model1 = make_pipeline(PolynomialFeatures(4), linear_model.LinearRegression())
    model1.fit( np.vstack(X1) , y1)

    model2 = make_pipeline(PolynomialFeatures(4), linear_model.LinearRegression())
    model2.fit( np.vstack(X2) , y2)


    res_1 = metrics.r2_score( y_true= y2, y_pred= model1.predict( np.vstack(X2) ) )
    res_2 = metrics.r2_score( y_true= y1, y_pred= model2.predict( np.vstack(X1) ) )

    res_tab_1.append(res_1)
    res_tab_1.append(res_2)  
    
    plt.figure(figsize=(6,6));
    axes = plt.gca()
    axes.set_xlim([0,1])
    axes.set_ylim([-1.5,1.5])
    plt.scatter(X1, y1,  color='blue')
    plt.scatter(X2, y2,  color='red')

    x_plot = np.vstack(np.linspace(0, 10, 1000))
    plt.plot(x_plot, model1.predict(x_plot), color='blue',linewidth=3)
    plt.plot(x_plot, model2.predict(x_plot), color='red',linewidth=3)

    plt.show()
    

    ############
    
    model1 = make_pipeline(PolynomialFeatures(4), linear_model.LinearRegression())
    model1.fit( np.vstack(X1) , y1)

    model2 = make_pipeline(PolynomialFeatures(4), linear_model.LinearRegression())
    model2.fit( np.vstack(X2) , y2)


    res_1 = metrics.r2_score( y_true= y2, y_pred= model1.predict( np.vstack(X2) ) )
    res_2 = metrics.r2_score( y_true= y1, y_pred= model2.predict( np.vstack(X1) ) )

    res_tab_2.append(res_1)
    res_tab_2.append(res_2)    

    ############    
    
    model1 = make_pipeline(PolynomialFeatures(5), linear_model.LinearRegression())
    model1.fit( np.vstack(X1) , y1)

    model2 = make_pipeline(PolynomialFeatures(5), linear_model.LinearRegression())
    model2.fit( np.vstack(X2) , y2)


    res_1 = metrics.r2_score( y_true= y2, y_pred= model1.predict( np.vstack(X2) ) )
    res_2 = metrics.r2_score( y_true= y1, y_pred= model2.predict( np.vstack(X1) ) )

    res_tab_3.append(res_1)
    res_tab_3.append(res_2)    

    ############    
    
    
    model1 = make_pipeline(PolynomialFeatures(7), linear_model.LinearRegression())
    model1.fit( np.vstack(X1) , y1)

    model2 = make_pipeline(PolynomialFeatures(7), linear_model.LinearRegression())
    model2.fit( np.vstack(X2) , y2)


    res_1 = metrics.r2_score( y_true= y2, y_pred= model1.predict( np.vstack(X2) ) )
    res_2 = metrics.r2_score( y_true= y1, y_pred= model2.predict( np.vstack(X1) ) )

    res_tab_4.append(res_1)
    res_tab_4.append(res_2)    

    ############    
    
    model1 = make_pipeline(PolynomialFeatures(10), linear_model.LinearRegression())
    model1.fit( np.vstack(X1) , y1)

    model2 = make_pipeline(PolynomialFeatures(10), linear_model.LinearRegression())
    model2.fit( np.vstack(X2) , y2)


    res_1 = metrics.r2_score( y_true= y2, y_pred= model1.predict( np.vstack(X2) ) )
    res_2 = metrics.r2_score( y_true= y1, y_pred= model2.predict( np.vstack(X1) ) )

    res_tab_5.append(res_1)
    res_tab_5.append(res_2)    

    ############    
    
    
#     print(res_1)
#     print(res_2)

# Plot outputs

# %%
plt.figure(figsize=(15,10))

plt.plot(res_tab_1, label = "1")
#plt.plot(res_tab_2, label = "4")
# plt.plot(res_tab_3, label = "5")
# plt.plot(res_tab_4, label = "7")
# plt.plot(res_tab_5, label = "10")
plt.legend()
plt.ylim(-24,2)
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn import datasets, linear_model

from sklearn import  metrics


model1 = make_pipeline(PolynomialFeatures(4), linear_model.LinearRegression())
model1.fit( np.vstack(X1) , y1)

model2 = make_pipeline(PolynomialFeatures(4), linear_model.LinearRegression())
model2.fit( np.vstack(X2) , y2)


res_1 = metrics.r2_score( y_true= y2, y_pred= model1.predict( np.vstack(X2) ) )
res_2 = metrics.r2_score( y_true= y1, y_pred= model2.predict( np.vstack(X1) ) )

print(res_1)
print(res_2)

# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,1])
axes.set_ylim([-1.5,1.5])
plt.scatter(X1, y1,  color='blue')
plt.scatter(X2, y2,  color='red')

x_plot = np.vstack(np.linspace(0, 10, 1000))
plt.plot(x_plot, model1.predict(x_plot), color='blue',linewidth=3)
plt.plot(x_plot, model2.predict(x_plot), color='red',linewidth=3)


plt.show()
# Out:
# 0.7909640162050944
# 0.633892007245662

# %% [markdown]
# # Zadanie
# Wykonaj regresję:
# * wielomianową stopnia $4$

# %% [markdown]
# # Zadanie
# Wykonaj regresję:
# * wielomianową stopnia $15$
